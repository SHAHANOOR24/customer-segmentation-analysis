# %%
import pandas as pd

df = pd.read_csv("clients_data.csv")
df.head()
# Out:
#    Customer_ID  Age Gender Item_Purchased  Category  Purchase_Amount_USD  \
# 0            1   55   Male         Blouse  Clothing                   53
# 1            2   19   Male        Sweater  Clothing                   64
# 2            3   50   Male          Jeans  Clothing                   73
# 3            4   21   Male        Sandals  Footwear                   90
# 4            5   45   Male         Blouse  Clothing                   49
#
#         Location Size      Color  Season  Review_Rating Subscription_Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#   Payment_Method  Shipping_Type Discount_Applied Promo_Code_Used  \
# 0    Credit Card        Express              Yes             Yes
# 1  Bank Transfer        Express              Yes             Yes
# 2           Cash  Free Shipping              Yes             Yes
# 3         PayPal   Next Day Air              Yes             Yes
# 4           Cash  Free Shipping              Yes             Yes
#
#    Previous_Purchases Preferred_Payment_Method Frequency_of_Purchases
# 0                  14                    Venmo            Fortnightly
# 1                   2                     Cash            Fortnightly
# 2                  23              Credit Card                 Weekly
# 3                  49                   PayPal                 Weekly
# 4                  31                   PayPal               Annually

# %%
features = df[['Age', 'Purchase_Amount_USD', 'Previous_Purchases']]

# %%
print(df[['Age', 'Purchase_Amount_USD', 'Previous_Purchases']].head())
print(df[['Age', 'Purchase_Amount_USD', 'Previous_Purchases']].shape)
# Out:
#    Age  Purchase_Amount_USD  Previous_Purchases
# 0   55                   53                  14
# 1   19                   64                   2
# 2   50                   73                  23
# 3   21                   90                  49
# 4   45                   49                  31
# (3900, 3)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(features)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(scaled_data)

# %%
df.groupby('Cluster').mean(numeric_only=True)
# Out:
#          Customer_ID        Age  Purchase_Amount_USD  Review_Rating  \
# Cluster
# 0        1926.399865  59.698917            58.569012       3.735792
# 1        2001.076625  36.332817            59.765480       3.748994
# 2        1924.194690  32.469027            61.326549       3.769558
#
#          Previous_Purchases
# Cluster
# 0                 28.451962
# 1                 11.018576
# 2                 37.684071
